# %% [markdown]
# # Recursion functions consists of base case and recursive case

# %%
def factorial(n):
    if n==0:     #base case
        return 1
    else:
        return n * factorial(n-1)   #recursive case

print(factorial(5))
# Out:
# 120

# %%
print(factorial(1900))
# Out:
# ...

# %%
print(factorial(15000))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(factorial(15000))
#
# Cell In[1], line 5, in factorial(n)
#       3     return 1
#       4 else:
# ----> 5     return n * factorial(n-1)
#
# Cell In[1], line 5, in factorial(n)
#       3     return 1
#       4 else:
# ----> 5     return n * factorial(n-1)
#
#     [... skipping similar frames: factorial at line 5 (2969 times)]
#
# Cell In[1], line 5, in factorial(n)
#       3     return 1
#       4 else:
# ----> 5     return n * factorial(n-1)
#
# Cell In[1], line 2, in factorial(n)
#       1 def factorial(n):
# ----> 2     if n==0:     #base case
#       3         return 1
#       4     else:
#
# RecursionError: maximum recursion depth exceeded in comparison

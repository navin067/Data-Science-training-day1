# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
# generate random numbers from a skewed normal distribution

x = np.random.standard_t(10, size=1000)
x[:15]
# Out:
# array([-0.11498184, -0.69383723,  0.69301304, -0.21910465, -0.11256458,
#        -1.04637215, -0.26769019,  0.75520167,  1.26676636,  1.01632704,
#         0.76398126, -1.99487872, -0.85825209, -0.65327741,  1.03492985])

# %%
plt.hist(x, color = "blue")
# Out:
# (array([  2.,   1.,  16.,  62., 151., 253., 277., 158.,  61.,  19.]),
#  array([-4.46607828, -3.72672734, -2.98737639, -2.24802545, -1.50867451,
#         -0.76932356, -0.02997262,  0.70937832,  1.44872927,  2.18808021,
#          2.92743115]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Mean

# %%
mean = np.mean(x)
print("Mean: ", mean)
# Out:
# Mean:  -0.01762943451184714

# %%
plt.hist(x, color = "blue")
plt.axvline(x = mean, color="yellow")

# %% [markdown]
# ## Median

# %%
median = np.median(x)
print("Median: ", median)
# Out:
# Median:  -0.0012995109895577697

# %%
plt.hist(x, color = "blue")
plt.axvline(x = median, color = "yellow")

# %% [markdown]
# ## Mode

# %%
mode = stats.mode(x).mode
print("Mode: ", mode)
# Out:
# Mode:  [-4.46607828]
# C:\Users\RAJARAM KHADKA\AppData\Local\Temp\ipykernel_10156\2897886845.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(x).mode

# %%
plt.hist(x, color="blue")
plt.axvline(x = mode, color = "yellow")
